# %% [markdown]
# # Notebook 03: Promptable Segmentation with SAM on Knee MRI
#
# Shows how to apply SAM/MedSAM to knee MRI with point and box prompts. Compares zero-shot vs fine-tuned performance, and demonstrates the interactive annotation workflow.
#
# **Status:** 🚧 In development — check back closer to the conference.
#
# **Session:** ISMRM 2026 Sunrise Course — Quantitative MSK MRI: From Acquisition to Analysis
# **Talk:** MSK MRI Segmentation & Registration Approaches (Gabrielle Hoyer)

# %%
# Coming soon

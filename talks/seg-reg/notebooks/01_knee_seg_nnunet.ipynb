# %% [markdown]
# # Notebook 01: Knee Cartilage Segmentation with nnU-Net
#
# Demonstrates inference with a pre-trained nnU-Net model on knee MRI (DESS) from the OAI/IWOAI dataset. Covers loading data with nibabel, running inference, visualizing overlays, and computing Dice + surface distance metrics.
#
# **Status:** 🚧 In development — check back closer to the conference.
#
# **Session:** ISMRM 2026 Sunrise Course — Quantitative MSK MRI: From Acquisition to Analysis
# **Talk:** MSK MRI Segmentation & Registration Approaches (Gabrielle Hoyer)

# %%
# Coming soon

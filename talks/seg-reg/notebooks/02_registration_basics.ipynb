# %% [markdown]
# # Notebook 02: Registration Basics — Rigid, Affine, and Deformable
#
# Walks through rigid bone alignment and deformable soft-tissue registration using SimpleITK. Includes overlay/checkerboard QA visualization and Jacobian determinant checks for plausibility.
#
# **Status:** 🚧 In development — check back closer to the conference.
#
# **Session:** ISMRM 2026 Sunrise Course — Quantitative MSK MRI: From Acquisition to Analysis
# **Talk:** MSK MRI Segmentation & Registration Approaches (Gabrielle Hoyer)

# %%
# Coming soon
